# %% [markdown]
# ### Importa as bibliotecas

# %%
import pandas as pd

# %% [markdown]
# ### Carrega o dataset

# %%
bullying = pd.read_csv('dados/original.csv', encoding='utf-8')

# %% [markdown]
# ### Lista o nome das colunas do dataset

# %%
list(bullying.columns.values)
# Out:
# ['Carimbo de data/hora',
#  'Digite o código de acesso',
#  'Qual a escola que você estuda?',
#  'Idade:',
#  'Ano escolar',
#  'Curso Técnico integrado ao Ensino Médio',
#  'Sexo',
#  'Orientação sexual',
#  'Escolaridade da mãe:',
#  'Escolaridade do pai:',
#  'Residência própria',
#  'Bairro onde mora',
#  'Trabalha?',
#  'Marque em caso afirmativo [a) Insultam-me]',
#  'Marque em caso afirmativo [b) Colocam-me apelidos vergonhosos]',
#  'Marque em caso afirmativo [c) Ameaçam-me]',
#  'Marque em caso afirmativo [d) Dizem coisas negativas sobre mim ou sobre minha família]',
#  'Marque em caso afirmativo [e) Fazem piada ou Insultam-me por causa de alguma característica física]',
#  'Marque em caso afirmativo [f) Levo socos, chutes e empurrões]',
#  'Marque em caso afirmativo [g) Riem de mim e me apontam]',
#  'Marque em caso afirmativo [h) Fazem com que os outros não gostem de mim]',
#  'Marque em caso afirmativo [i) Inventam que eu furto coisas de meus colegas]',
# ...

# %% [markdown]
# ### Renomeia nome de colunas para o formato col_XX

# %%
columns = list(bullying.columns)
columns = ['col_' + "{:02d}".format(i) for i in range(0, 46)]
bullying.columns = columns

# %% [markdown]
# ### Coluna 01

# %%
bullying['col_01'].value_counts(dropna=False)
# Out:
# PDHB-PTL                        135
# PDHB-SVC                        117
# PDHB-SNP                        115
# PDHB-BLV                         89
# PDHB-EAE                         48
# PDHB                             31
# PDHB-SES                         23
# PDHB SVC                         12
#  PDHB-SVC                         9
# PDHB-EDS                          8
# PDHB-svc                          4
#  PDHB-SES                         4
# PDHB-BLV                          4
#  PDHB-EDS                         3
# PDHB-CVC                          2
# PDHB  SVC                         2
# PDHBBLV                           2
# PDHB_PTL                          2
# PDHB-PTL                          2
# PDHB/SNP                          2
# PDHB-ptl                          1
# Código: PDHB-PTL                  1
# PDHB-PLT                          1
# PDHB - SVC                        1
# PDHB_SVC                          1
# PDHB-OTL                          1
# ...

# %%
bullying['col_01'] = bullying['col_01'].str.replace('PDHB','OC')

# %%
bullying['col_01'] = bullying['col_01'].str.replace('ALV','-BMR')
bullying['col_01'] = bullying['col_01'].str.replace('BLV','-CMR')
bullying['col_01'] = bullying['col_01'].str.replace('CVC','-DXD')
bullying['col_01'] = bullying['col_01'].str.replace('EAE','-FBF')
bullying['col_01'] = bullying['col_01'].str.replace('EDS','-FET')
bullying['col_01'] = bullying['col_01'].str.replace('PLT','-RMU')
bullying['col_01'] = bullying['col_01'].str.replace('PTL','-RUM')
bullying['col_01'] = bullying['col_01'].str.replace('ptl','-rum')
bullying['col_01'] = bullying['col_01'].str.replace('OTL','-PUM')
bullying['col_01'] = bullying['col_01'].str.replace('SES','-TFT')
bullying['col_01'] = bullying['col_01'].str.replace('SNP','-TOQ')
bullying['col_01'] = bullying['col_01'].str.replace('snp','-toq')
bullying['col_01'] = bullying['col_01'].str.replace('SVC','-TXD')
bullying['col_01'] = bullying['col_01'].str.replace('svc','-txd')
bullying['col_01'] = bullying['col_01'].str.replace('BL', '-CM')
bullying['col_01'] = bullying['col_01'].str.replace('LV', '-MR')

# %%
bullying['col_01'].value_counts()
# Out:
# OC--RUM                        135
# OC--TXD                        117
# OC--TOQ                        115
# OC--CMR                         89
# OC--FBF                         48
# OC                              31
# OC--TFT                         23
# OC -TXD                         12
#  OC--TXD                         9
# OC--FET                          8
#  OC--TFT                         4
# OC--txd                          4
# OC--CMR                          4
#  OC--FET                         3
# OC-CMR                           2
# OC--DXD                          2
# OC--RUM                          2
# OC/-TOQ                          2
# OC_-RUM                          2
# OC  -TXD                         2
# OC                               1
# OC--CM                           1
# OC-FBF                           1
# OC--TXD                          1
# OC--rum                          1
#  OC--CMR                         1
# OC_-TXD                          1
# ...

# %% [markdown]
# ### Coluna 03

# %%
bullying['col_03'].value_counts(dropna=False)
# Out:
# 15              181
# 16              164
# 17              100
# 18               41
# 14               32
# 15 anos          21
# NaN              18
# 16 anos          12
# 19               11
# 16 ANOS           8
# 17 anos           6
# 15 ANOS           5
# 15 anos           5
# 18 anos           4
# 16 anos           3
# 18 ANOS           2
# 15 ANOS           2
# 14 ANOS           2
# 16 Anos           1
# 17 anos           1
# 17 ANOS           1
# 15 Anos           1
# 15.               1
# 14 anos           1
# 17 ANOS           1
# 20                1
# 15 anos.          1
# 19 anos           1
# 22                1
# 16 ano            1
#  16 Anos          1
# 13                1
# 16 ANOS           1
# FELIPIHE PJL      1
# 43                1
# Name: col_03, dtype: int64

# %%
bullying['col_03'] = bullying['col_03'].str.replace('FELIPIHE PJL','FEL LJP')

# %%
bullying['col_03'].value_counts(dropna=False)
# Out:
# 15          181
# 16          164
# 17          100
# 18           41
# 14           32
# 15 anos      21
# NaN          18
# 16 anos      12
# 19           11
# 16 ANOS       8
# 17 anos       6
# 15 ANOS       5
# 15 anos       5
# 18 anos       4
# 16 anos       3
# 15 ANOS       2
# 14 ANOS       2
# 18 ANOS       2
# 17 anos       1
# 16 Anos       1
# 17 ANOS       1
# 15 Anos       1
# 15.           1
# 14 anos       1
# 17 ANOS       1
# 20            1
# 15 anos.      1
# FEL LJP       1
# 19 anos       1
# 22            1
# 16 ano        1
#  16 Anos      1
# 13            1
# 16 ANOS       1
# 43            1
# Name: col_03, dtype: int64

# %% [markdown]
# ### Coluna 04

# %%
bullying['col_04'].value_counts(dropna=False)
# Out:
# 1º Ano do Ensino Médio    261
# 2º Ano do Ensino Médio    190
# 3º Ano do Ensino Médio    126
# 4º ano Ensino Médio        39
# NaN                        18
# Name: col_04, dtype: int64

# %% [markdown]
# ### Coluna 06

# %%
bullying['col_06'].value_counts(dropna=False)
# Out:
# Masculino    330
# Feminino     286
# NaN           18
# Name: col_06, dtype: int64

# %% [markdown]
# ### Coluna 07

# %%
bullying['col_07'].value_counts(dropna=False)
# Out:
# Heterossexual       526
# NaN                  54
# Bissexual            32
# Homossexual          16
# bissexual             1
# Chinês                1
# Transsexualidade      1
# Pansexual             1
# HOMEM MACHO           1
# Heterossexual         1
# Name: col_07, dtype: int64

# %% [markdown]
# ### Coluna 13

# %%
bullying['col_13'].value_counts(dropna=False)
# Out:
# Nenhuma Vez      329
# Algumas Vezes    250
# Muitas Vezes      37
# NaN               18
# Name: col_13, dtype: int64

# %% [markdown]
# ### Coluna 14

# %%
bullying['col_14'].value_counts(dropna=False)
# Out:
# Nenhuma Vez      322
# Algumas Vezes    235
# Muitas Vezes      59
# NaN               18
# Name: col_14, dtype: int64

# %% [markdown]
# ### Coluna 15

# %%
bullying['col_15'].value_counts(dropna=False)
# Out:
# Nenhuma Vez      553
# Algumas Vezes     54
# NaN               18
# Muitas Vezes       9
# Name: col_15, dtype: int64

# %% [markdown]
# ### Coluna 16

# %%
bullying['col_16'].value_counts(dropna=False)
# Out:
# Nenhuma Vez      407
# Algumas Vezes    179
# Muitas Vezes      30
# NaN               18
# Name: col_16, dtype: int64

# %% [markdown]
# ### Coluna 17

# %%
bullying['col_17'].value_counts(dropna=False)
# Out:
# Nenhuma Vez      319
# Algumas Vezes    220
# Muitas Vezes      77
# NaN               18
# Name: col_17, dtype: int64

# %% [markdown]
# ### Coluna 18

# %%
bullying['col_18'].value_counts(dropna=False)
# Out:
# Nenhuma Vez      548
# Algumas Vezes     55
# NaN               18
# Muitas Vezes      13
# Name: col_18, dtype: int64

# %% [markdown]
# ### Coluna 19

# %%
bullying['col_19'].value_counts(dropna=False)
# Out:
# Nenhuma Vez      447
# Algumas Vezes    146
# Muitas Vezes      23
# NaN               18
# Name: col_19, dtype: int64

# %% [markdown]
# ### Coluna 20

# %%
bullying['col_20'].value_counts(dropna=False)
# Out:
# Nenhuma Vez      483
# Algumas Vezes    107
# Muitas Vezes      26
# NaN               18
# Name: col_20, dtype: int64

# %% [markdown]
# ### Coluna 21

# %%
bullying['col_21'].value_counts(dropna=False)
# Out:
# Nenhuma Vez      548
# Algumas Vezes     48
# Muitas Vezes      20
# NaN               18
# Name: col_21, dtype: int64

# %% [markdown]
# ### Coluna 22

# %%
bullying['col_22'].value_counts(dropna=False)
# Out:
# Nenhuma Vez      574
# Algumas Vezes     31
# NaN               18
# Muitas Vezes      11
# Name: col_22, dtype: int64

# %% [markdown]
# ### Define campos a serem exportados

# %%
bullying.rename(columns={'col_01':'local'}, inplace=True)
bullying.rename(columns={'col_03':'idade'}, inplace=True)
bullying.rename(columns={'col_04':'ano_escolar'}, inplace=True)
bullying.rename(columns={'col_06':'sexo'}, inplace=True)
bullying.rename(columns={'col_07':'orientacao'}, inplace=True)

# %%
bullying.rename(columns={'col_13':'questao_01'}, inplace=True)
bullying.rename(columns={'col_14':'questao_02'}, inplace=True)
bullying.rename(columns={'col_15':'questao_03'}, inplace=True)
bullying.rename(columns={'col_16':'questao_04'}, inplace=True)
bullying.rename(columns={'col_17':'questao_05'}, inplace=True)
bullying.rename(columns={'col_18':'questao_06'}, inplace=True)
bullying.rename(columns={'col_19':'questao_07'}, inplace=True)
bullying.rename(columns={'col_20':'questao_08'}, inplace=True)
bullying.rename(columns={'col_21':'questao_09'}, inplace=True)
bullying.rename(columns={'col_22':'questao_10'}, inplace=True)

# %%
columns = []
for item in list(bullying.columns):
    if item.find('col_')==-1:
        columns.append(item)

# %% [markdown]
# ### Salva o arquivo mascarado

# %%
bullying.to_csv('dados/bullying.csv', columns=columns, sep=';', index=False)
